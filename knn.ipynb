# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
import pandas as pd
df = pd.read_csv('/content/iphone_purchase_records.csv')
df.head(100)
# Out:
#     Gender  Age  Salary  Purchase Iphone
# 0     Male   19   19000                0
# 1     Male   35   20000                0
# 2   Female   26   43000                0
# 3   Female   27   57000                0
# 4     Male   19   76000                0
# ..     ...  ...     ...              ...
# 95  Female   35   44000                0
# 96  Female   35   25000                0
# 97    Male   28  123000                1
# 98    Male   35   73000                0
# 99  Female   28   37000                0
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    object
#  1   Age              400 non-null    int64
#  2   Salary           400 non-null    int64
#  3   Purchase Iphone  400 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 12.6+ KB

# %%
df.shape
# Out:
# (400, 4)

# %%
# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()
# df = label_encoder.fit_transform(df['Gender'])

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder


df = pd.read_csv('/content/iphone_purchase_records.csv')


label_encoder = LabelEncoder()

df['Gender_Encoded'] = label_encoder.fit_transform(df['Gender'])


print(df.head())
# Out:
#    Gender  Age  Salary  Purchase Iphone  Gender_Encoded
# 0    Male   19   19000                0               1
# 1    Male   35   20000                0               1
# 2  Female   26   43000                0               0
# 3  Female   27   57000                0               0
# 4    Male   19   76000                0               1

# %%
df = df.drop('Gender', axis=1)

# %%
print(df.head())
# Out:
#    Age  Salary  Purchase Iphone  Gender_Encoded
# 0   19   19000                0               1
# 1   35   20000                0               1
# 2   26   43000                0               0
# 3   27   57000                0               0
# 4   19   76000                0               1

# %%
X = df[['Age', 'Salary', 'Gender_Encoded']]  # Select features for X
Y = df['Purchase Iphone']  # Select target for Y

print(X.head())  # To see the first few rows of X
print(Y.head())  # To see the first few rows of Y
# Out:
#    Age  Salary  Gender_Encoded
# 0   19   19000               1
# 1   35   20000               1
# 2   26   43000               0
# 3   27   57000               0
# 4   19   76000               1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchase Iphone, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=7)

# %%
clf = KNeighborsClassifier()
clf.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
score = clf.score(X_train,Y_train)
print(clf.predict([[19,19000,1]]))
# Out:
# [0]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
predict = clf.predict(X_test)
print(classification_report(Y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88        54
#            1       0.80      0.62      0.70        26
#
#     accuracy                           0.82        80
#    macro avg       0.82      0.77      0.79        80
# weighted avg       0.82      0.82      0.82        80

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
import pandas as pd
df = pd.read_csv('/content/KNNAlgorithmDataset.csv')
df.head(100)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# ..       ...       ...          ...           ...             ...        ...
# 95     86208         M       20.260         23.03          132.40     1264.0
# 96     86211         B       12.180         17.84           77.79      451.1
# 97    862261         B        9.787         19.94           62.11      294.5
# 98    862485         B       11.600         12.84           74.34      412.6
# 99    862548         M       14.420         19.77           94.48      642.5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
label_encoder = LabelEncoder()
df['diagnosis'] = label_encoder.fit_transform(df['diagnosis'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
X = df[['id','radius_mean']]  # Select features for X
Y = df['diagnosis']  # Select target for Y

#print(X.head())  # To see the first few rows of X
df.diagnosis
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=7)

# %%
clf = KNeighborsClassifier(n_neighbors=2)
clf.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
score = clf.score(X_test,Y_test)
#print(clf.predict(X_test))
score
# Out:
# 0.6666666666666666

# %%
predict = clf.predict(X_test)
print(classification_report(Y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.89      0.78        74
#            1       0.56      0.25      0.34        40
#
#     accuracy                           0.67       114
#    macro avg       0.62      0.57      0.56       114
# weighted avg       0.64      0.67      0.63       114
