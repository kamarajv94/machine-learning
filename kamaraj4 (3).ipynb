# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
data=pd.read_csv('/content/Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
x=data['User ID'].values.reshape(-1,1)
y=data['EstimatedSalary'].values.ravel()

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x,y)
print(model.score(x,y))
# Out:
# 1.0

# %%
print(model.predict([[15668575]]))
# Out:
# [43000]

# %%
import numpy as np
x=np.array(x)
y=np.array(y)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=7)

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report
predictions = model.predict(x_test)
print("predicted value",predictions)
print("original value",y_test)
# Out:
# predicted value [ 31000  70000  77000  27000  63000  15000  55000  57000  47000  80000
#  122000  41000  47000  32000 148000 116000  18000  29000  83000  51000
#   80000  65000 130000  52000  74000  27000  23000  49000 117000  83000
#   41000  39000  38000  88000  60000  63000  17000  57000  32000  64000
#  115000  75000 141000  83000  80000  82000  15000 141000 100000  52000
#   43000  32000  22000  51000  75000 116000  86000  79000 141000  68000
#   43000  70000  43000 106000  55000 117000 134000  26000 104000  19000
#  122000  86000 134000  60000  89000  21000 148000 108000 102000  58000
#  144000 131000  82000 117000 134000  53000  23000  44000  72000 104000
#   33000  44000  66000  19000  18000  22000  15000 141000  77000 102000]
# original value [108000  58000  75000  87000  87000  28000 138000  71000  88000  69000
#   48000  26000  15000  72000  80000  42000  59000  79000  75000  74000
#   83000  59000  20000  23000  74000  63000 146000  89000  42000  47000
#   72000  82000  59000  72000  20000 129000  44000 114000  79000  50000
#   41000  22000  50000  54000  80000 104000  84000  80000  43000  51000
#   57000  41000 135000  73000  96000  65000 144000  80000  33000  80000
#   61000  34000  71000 119000  81000  51000  65000  82000  65000  39000
#   60000  89000  88000 107000  80000  91000 117000  50000  18000  17000
#  133000  73000  42000  32000  72000  71000  30000  39000  23000  90000
#   85000  54000 131000  26000  72000  79000  19000  79000  86000  59000]

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#        15000       0.00      0.00      0.00         1
#        17000       0.00      0.00      0.00         1
#        18000       0.00      0.00      0.00         1
#        19000       0.00      0.00      0.00         1
#        20000       0.00      0.00      0.00         2
#        21000       0.00      0.00      0.00         0
#        22000       0.00      0.00      0.00         1
#        23000       0.00      0.00      0.00         2
#        26000       0.00      0.00      0.00         2
#        27000       0.00      0.00      0.00         0
#        28000       0.00      0.00      0.00         1
#        29000       0.00      0.00      0.00         0
#        30000       0.00      0.00      0.00         1
#        31000       0.00      0.00      0.00         0
#        32000       0.00      0.00      0.00         1
#        33000       0.00      0.00      0.00         1
#        34000       0.00      0.00      0.00         1
#        38000       0.00      0.00      0.00         0
#        39000       0.00      0.00      0.00         2
#        41000       0.00      0.00      0.00         2
#        42000       0.00      0.00      0.00         3
#        43000       0.00      0.00      0.00         1
#        44000       0.00      0.00      0.00         1
#        47000       0.00      0.00      0.00         1
#        48000       0.00      0.00      0.00         1
#        49000       0.00      0.00      0.00         0
#        50000       0.00      0.00      0.00         3
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
x=data['id'].values.reshape(-1,1)
y=data['diagnosis'].values.ravel()

# %%
from sklearn.tree import DecisionTreeClassifier
clf= DecisionTreeClassifier()
clf.fit(x,y)
print(clf.score(x,y))
# Out:
# 1.0

# %%
print(clf.predict([[842302]]))
# Out:
# ['M']

# %%
import numpy as np
x=np.array(x)
y=np.array(y)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=7)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report
predictions = clf.predict(x_test)
print("predicted value",predictions)
print("original value",y_test)
# Out:
# predicted value ['B' 'M' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'M'
#  'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B'
#  'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B'
#  'M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'M' 'M'
#  'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'M']
# original value ['B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B'
#  'M' 'M' 'M' 'M' 'M' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'B'
#  'M' 'M' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'M' 'M' 'B' 'B'
#  'M' 'B' 'B' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M']

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.76      0.63      0.69        98
#            M       0.41      0.56      0.47        45
#
#     accuracy                           0.61       143
#    macro avg       0.58      0.59      0.58       143
# weighted avg       0.65      0.61      0.62       143
